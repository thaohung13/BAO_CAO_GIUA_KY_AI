# %% [markdown]
# <a href="https://colab.research.google.com/github/thaohung13/BAO_CAO_GIUA_KY_AI/blob/main/Bai2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#tải tập dữ liệu hình ảnh, chuyển đổi chúng thành mảng NumPy,
#và lưu các mảng này vào đĩa để sử dụng trong quá trình đào tạo hoặc kiểm tra mô hình.
from os import listdir               # lấy danh sách tệp trong thư mục huấn luyện
from numpy import asarray            # chuyển đổi danh sách ảnh và nhãn thành mảng NumPy
from numpy import save               # lưu thành tệp
from keras.utils import load_img     # load_img: để tải ảnh từ tệp
from keras.utils import img_to_array # img_to_array: chuyển đổi thành mảng NumPy
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np
# khai báo các thành phần cần thiết để xây dựng một mô hình mạng neural 
from keras.saving.saving_lib import load_model
from keras.models import Sequential,Model
from keras.layers import Dense,Flatten,Dropout,Conv2D,MaxPooling2D,Normalization,Input,LeakyReLU
from keras.optimizers import Adam
from keras.losses import categorical_crossentropy
from keras import losses
loss = losses
batch_size = 32
epochs = 150
classes = 9

# %%
# đoạn mã này được sử dụng để tải các tệp ảnh và nhãn tương ứng từ thư mục trên Google Drive
# chuẩn bị chúng cho việc huấn luyện mô hình học máy.
folder = '/content/drive/MyDrive/BAI3/'
photos, labels = list(), list()
for file in listdir(folder):
  output= 0
  if file.startswith('5k'):
    output= 1
  if file.startswith('10k'):
    output= 2
  if file.startswith('20k'):
    output= 3
  if file.startswith('30k'):
    output= 4
  if file.startswith('50k'):
    output= 5
  if file.startswith('100k'):
    output= 6
  if file.startswith('200k'):
    output= 7  
  if file.startswith('500k'):
    output= 8
  photo = load_img(folder + file, target_size= (40,40))
  photo = img_to_array(photo) # Chuyển đổi ảnh thành một mảng NumPy
  photos.append(photo)  # Thêm mảng ảnh vào danh sách photos
  labels.append(output) # Thêm giá trị output tương ứng vào danh sách labels

# %%
# lưu trữ các mảng numpy photos và labels
photos= asarray(photos) # Chuyển danh sách ảnh thành một mảng NumPy
labels= asarray(labels) # Chuyển danh sách nhãn thành một mảng NumPy
print(photos.shape, labels.shape) # In ra kích thước của mảng ảnh và mảng nhãn
# photos.shape trả về kích thước của mảng photos, được biểu diễn dưới dạng một tuple (số lượng phần tử theo chiều dọc, số lượng phần tử theo chiều ngang, số lượng kênh màu)
# labels.shape: trả về ảnh
save('/content/drive/MyDrive/model/money/MONEY_photos', photos)
save('/content/drive/MyDrive/model/money/MONEY_labels', labels)
# Out:
# (88, 40, 40, 3) (88,)

# %%
split_index = int(0.2 * len(photos))
test_x, test_y = photos[:split_index], labels[:split_index]
train_x, train_y = photos[split_index:], labels[split_index:]

# %%
print(test_x.shape, train_x.shape)
# Out:
# (17, 40, 40, 3) (71, 40, 40, 3)

# %%
#về khoảng giá trị từ 0 đến 1 bằng cách chia tất cả các giá trị pixel cho 255
train_x = train_x.reshape((71,40, 40, 3))
train_x = train_x.astype('float32')/255

test_x = test_x.reshape((17,40, 40, 3))
test_x = test_x.astype('float32')/255

# %%
from keras.utils import to_categorical
train_y = to_categorical(train_y,9)
test_y = to_categorical(test_y,9)

# %%
# khởi tạo một mô hình mạng neural convolutional (CNN) 
model = Sequential()
model.add(Conv2D(32, kernel_size = (3,3), activation = 'linear', input_shape = (40, 40, 3), padding= 'same'))
model.add(LeakyReLU(alpha = 0.1))

model.add(MaxPooling2D((2,2), padding = 'same'))
model.add(Conv2D(64, (3,3), activation = 'linear', padding = 'same'))
model.add(Conv2D(64, (3,3), activation = 'linear', padding = 'same'))
model.add(LeakyReLU(alpha = 0.1))

model.add(MaxPooling2D((2,2), padding = 'same'))
model.add(Conv2D(128, (3,3), activation = 'linear', padding = 'same'))
model.add(LeakyReLU(alpha = 0.1))

model.add(MaxPooling2D((2,2), padding = 'same'))
model.add(Conv2D(256, (3,3), activation = 'linear', padding = 'same'))
model.add(LeakyReLU(alpha = 0.1))

model.add(MaxPooling2D((2,2), padding = 'same'))
model.add(Conv2D(512, (3,3), activation = 'linear', padding = 'same'))
model.add(LeakyReLU(alpha = 0.1))

model.add(MaxPooling2D((2,2), padding = 'same'))
model.add(Conv2D(1024, (3,3), activation = 'linear', padding = 'same'))
model.add(LeakyReLU(alpha = 0.1))
#Đưa vào ANN, bộ ANN để phân loại:
model.add(Flatten())
model.add(Dense(1024, activation = 'linear'))
model.add(Dropout(0.25))
model.add(Dense(256,activation = 'relu'))
model.add(Dropout(0.25))
model.add(Dense(512,activation = 'relu'))
model.add(Dropout(0.25))
model.add(Dense(classes, activation = 'softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 40, 40, 32)        896
#
#  leaky_re_lu (LeakyReLU)     (None, 40, 40, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 20, 20, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 20, 20, 64)        18496
#
#  conv2d_2 (Conv2D)           (None, 20, 20, 64)        36928
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 20, 20, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 10, 10, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 10, 10, 128)       73856
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 10, 10, 128)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 5, 5, 128)        0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 5, 5, 256)         295168
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 5, 5, 256)         0
#
#  max_pooling2d_3 (MaxPooling  (None, 3, 3, 256)        0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 3, 3, 512)         1180160
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 3, 3, 512)         0
#
#  max_pooling2d_4 (MaxPooling  (None, 2, 2, 512)        0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 2, 2, 1024)        4719616
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 2, 2, 1024)        0
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 1024)              4195328
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 256)               262400
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 512)               131584
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 9)                 4617
#
# =================================================================
# Total params: 10,919,049
# Trainable params: 10,919,049
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Compile:
model.compile(optimizer = Adam(), loss = 'categorical_crossentropy', metrics = ['accuracy'])
train = model.fit(train_x, train_y, batch_size= batch_size,epochs= epochs, verbose= 1)
eval = model.evaluate(test_x, test_y)
print('Test loss: ', eval[0])
print('Test accuracy: ', eval[1])
# Out:
# Epoch 1/150
# 3/3 [==============================] - 7s 2s/step - loss: 2.2811 - accuracy: 0.2394
# Epoch 2/150
# 3/3 [==============================] - 5s 1s/step - loss: 2.0655 - accuracy: 0.1408
# Epoch 3/150
# 3/3 [==============================] - 5s 2s/step - loss: 1.9111 - accuracy: 0.3803
# Epoch 4/150
# 3/3 [==============================] - 7s 2s/step - loss: 2.5780 - accuracy: 0.4085
# Epoch 5/150
# 3/3 [==============================] - 5s 1s/step - loss: 1.9227 - accuracy: 0.3662
# Epoch 6/150
# 3/3 [==============================] - 5s 2s/step - loss: 1.8362 - accuracy: 0.3380
# Epoch 7/150
# 3/3 [==============================] - 6s 1s/step - loss: 1.7749 - accuracy: 0.3944
# Epoch 8/150
# 3/3 [==============================] - 5s 1s/step - loss: 1.7825 - accuracy: 0.4085
# Epoch 9/150
# 3/3 [==============================] - 6s 2s/step - loss: 1.7387 - accuracy: 0.3944
# Epoch 10/150
# 3/3 [==============================] - 5s 1s/step - loss: 1.7702 - accuracy: 0.3944
# Epoch 11/150
# 3/3 [==============================] - 6s 2s/step - loss: 1.7456 - accuracy: 0.3662
# Epoch 12/150
# 3/3 [==============================] - 5s 1s/step - loss: 1.7593 - accuracy: 0.3803
# Epoch 13/150
# 3/3 [==============================] - 5s 1s/step - loss: 1.6846 - accuracy: 0.4085
# Epoch 14/150
# 3/3 [==============================] - 6s 2s/step - loss: 1.6565 - accuracy: 0.4085
# Epoch 15/150
# 3/3 [==============================] - 5s 1s/step - loss: 1.6651 - accuracy: 0.4085
# Epoch 16/150
# 3/3 [==============================] - 5s 1s/step - loss: 1.7149 - accuracy: 0.4085
# Epoch 17/150
# 3/3 [==============================] - 6s 2s/step - loss: 1.6889 - accuracy: 0.4085
# Epoch 18/150
# 3/3 [==============================] - 5s 1s/step - loss: 1.6510 - accuracy: 0.4085
# Epoch 19/150
# 3/3 [==============================] - 6s 2s/step - loss: 1.6192 - accuracy: 0.4366
# Epoch 20/150
# 3/3 [==============================] - 5s 1s/step - loss: 1.6022 - accuracy: 0.4085
# Epoch 21/150
# 3/3 [==============================] - 5s 1s/step - loss: 1.6361 - accuracy: 0.4085
# Epoch 22/150
# 3/3 [==============================] - 6s 2s/step - loss: 1.6009 - accuracy: 0.4085
# Epoch 23/150
# 3/3 [==============================] - 5s 1s/step - loss: 1.5402 - accuracy: 0.4085
# Epoch 24/150
# 3/3 [==============================] - 7s 2s/step - loss: 1.5191 - accuracy: 0.4085
# Epoch 25/150
# 3/3 [==============================] - 5s 1s/step - loss: 1.4532 - accuracy: 0.4085
# Epoch 26/150
# 3/3 [==============================] - 6s 2s/step - loss: 1
150
# 3/3 [==============================] - 5s 1s/step - loss: 0.6297 - accuracy: 0.8169
# Epoch 83/150
# 3/3 [==============================] - 7s 2s/step - loss: 0.5643 - accuracy: 0.7887
# Epoch 84/150
# 3/3 [==============================] - 5s 2s/step - loss: 0.4651 - accuracy: 0.8169
# Epoch 85/150
# 3/3 [==============================] - 6s 2s/step - loss: 0.4100 - accuracy: 0.8451
# Epoch 86/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.2786 - accuracy: 0.8732
# Epoch 87/150
# 3/3 [==============================] - 5s 2s/step - loss: 0.2609 - accuracy: 0.9155
# Epoch 88/150
# 3/3 [==============================] - 7s 2s/step - loss: 0.1790 - accuracy: 0.9437
# Epoch 89/150
# 3/3 [==============================] - 6s 2s/step - loss: 0.1228 - accuracy: 0.9718
# Epoch 90/150
# 3/3 [==============================] - 7s 2s/step - loss: 0.0976 - accuracy: 0.9577
# Epoch 91/150
# 3/3 [==============================] - 6s 2s/step - loss: 0.1067 - accuracy: 0.9437
# Epoch 92/150
# 3/3 [==============================] - 6s 2s/step - loss: 0.0781 - accuracy: 0.9859
# Epoch 93/150
# 3/3 [==============================] - 6s 2s/step - loss: 0.0942 - accuracy: 0.9859
# Epoch 94/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.5559 - accuracy: 0.9155
# Epoch 95/150
# 3/3 [==============================] - 7s 2s/step - loss: 1.4519 - accuracy: 0.8028
# Epoch 96/150
# 3/3 [==============================] - 5s 1s/step - loss: 1.4105 - accuracy: 0.7183
# Epoch 97/150
# 3/3 [==============================] - 6s 2s/step - loss: 1.8283 - accuracy: 0.7183
# Epoch 98/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.9655 - accuracy: 0.7324
# Epoch 99/150
# 3/3 [==============================] - 6s 2s/step - loss: 0.8775 - accuracy: 0.7606
# Epoch 100/150
# 3/3 [==============================] - 7s 2s/step - loss: 1.3611 - accuracy: 0.7324
# Epoch 101/150
# 3/3 [==============================] - 6s 2s/step - loss: 0.8353 - accuracy: 0.6901
# Epoch 102/150
# 3/3 [==============================] - 6s 2s/step - loss: 0.7184 - accuracy: 0.7606
# Epoch 103/150
# 3/3 [==============================] - 5s 2s/step - loss: 0.3876 - accuracy: 0.8732
# Epoch 104/150
# 3/3 [==============================] - 6s 2s/step - loss: 0.2977 - accuracy: 0.8732
# Epoch 105/150
# 3/3 [==============================] - 6s 2s/step - loss: 0.2432 - accuracy: 0.9296
# Epoch 106/150
# 3/3 [==============================] - 5s 2s/step - loss: 0.2257 - accuracy: 0.8873
# Epoch 107/150
# 3/3 [==============================] - 7s 2s/step - loss: 0.2568 - accuracy: 0.8873
# Epoch 108/150
# 3/3 [==============================] - 6s 2s/step - loss: 0.1248 - accuracy: 0.9718
# Epoch 109/150
# 3/3 [==============================] - 7s 2s/step - loss: 0.3628 - accuracy: 0.9155
# Epoch 110/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.5835 - accuracy: 0.9014
# Epoch 111/150
# 3/3 [==============================] - 6s 2s/step - loss: 0.2255 - accuracy: 0.8732
# Epoch 112/150
# 3/3 [==============================] - 6s 1s/step - loss: 0.3089 - accuracy: 0.8592
# Epoch 113/150
# 3/3 [==============================] - 6s 2s/step - loss: 0.9280 - accuracy: 0.8873
# Epoch 114/150
# 3/3 [==============================] - 6s 2s/step - loss: 0.5849 - accuracy: 0.8451
# Epoch 115/150
# 3/3 [==============================] - 6s 1s/step - loss: 0.1640 - accuracy: 0.9718
# Epoch 116/150
# 3/3 [==============================] - 7s 2s/step - loss: 0.2437 - accuracy: 0.9155
# Epoch 117/150
# 3/3 [==============================] - 6s 2s/step - loss: 0.1322 - accuracy: 0.9718
# Epoch 118/150
# 3/3 [==============================] - 6s 2s/step - loss: 0.0905 - accuracy: 0.9718
# Epoch 119/150
# 3/3 [==============================] - 6s 2s/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 120/150
# 3/3 [==============================] - 6s 2s/step - loss: 0.0287 - accuracy: 0.9859
# Epoch 121/150
# 3/3 [==============================] - 6s 1s/step - loss: 0.0157 - accuracy: 1.0000
# Epoch 122/150
# 3/3 [==============================] - 6s 2s/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 123/150
# 3/3 [==============================] - 7s 2s/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 124/150
# 3/3 [==============================] - 6s 2s/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 125/150
# 3/3 [==============================] - 7s 2s/step - loss: 4.1918e-04 - accuracy: 1.0000
# Epoch 126/150
# 3/3 [==============================] - 6s 2s/step - loss: 6.2337e-04 - accuracy: 1.0000
# Epoch 127/150
# 3/3 [==============================] - 6s 2s/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 128/150
# 3/3 [==============================] - 6s 2s/step - loss: 4.3986e-04 - accuracy: 1.0000
# Epoch 129/150
# 3/3 [==============================] - 6s 2s/step - loss: 7.5033e-04 - accuracy: 1.0000
# Epoch 130/150
# 3/3 [==============================] - 6s 2s/step - loss: 1.7654e-04 - accuracy: 1.0000
# Epoch 131/150
# 3/3 [==============================] - 6s 2s/step - loss: 5.3173e-04 - accuracy: 1.0000
# Epoch 132/150
# 3/3 [==============================] - 7s 2s/step - loss: 1.3522e-04 - accuracy: 1.0000
# Epoch 133/150
# 3/3 [==============================] - 5s 2s/step - loss: 2.8911e-04 - accuracy: 1.0000
# Epoch 134/150
# 3/3 [==============================] - 7s 2s/step - loss: 4.3372e-05 - accuracy: 1.0000
# Epoch 135/150
# 3/3 [==============================] - 6s 2s/step - loss: 6.9464e-05 - accuracy: 1.0000
# Epoch 136/150
# 3/3 [==============================] - 5s 1s/step - loss: 5.1553e-05 - accuracy: 1.0000
# Epoch 137/150
# 3/3 [==============================] - 7s 2s/step - loss: 1.8863e-04 - accuracy: 1.0000
# Epoch 138/150
# 3/3 [==============================] - 5s 1s/step - loss: 2.0842e-04 - accuracy: 1.0000
# Epoch 139/150
# 3/3 [==============================] - 7s 2s/step - loss: 1.4639e-04 - accuracy: 1.0000
# Epoch 140/150
# 3/3 [==============================] - 6s 1s/step - loss: 9.0484e-05 - accuracy: 1.0000
# Epoch 141/150
# 3/3 [==============================] - 6s 2s/step - loss: 3.1466e-05 - accuracy: 1.0000
# Epoch 142/150
# 3/3 [==============================] - 6s 2s/step - loss: 1.0184e-04 - accuracy: 1.0000
# Epoch 143/150
# 3/3 [==============================] - 6s 2s/step - loss: 7.0282e-04 - accuracy: 1.0000
# Epoch 144/150
# 3/3 [==============================] - 7s 2s/step - loss: 1.0065e-05 - accuracy: 1.0000
# Epoch 145/150
# 3/3 [==============================] - 6s 2s/step - loss: 1.3423e-04 - accuracy: 1.0000
# Epoch 146/150
# 3/3 [==============================] - 7s 1s/step - loss: 2.5293e-04 - accuracy: 1.0000
# Epoch 147/150
# 3/3 [==============================] - 6s 2s/step - loss: 1.9170e-05 - accuracy: 1.0000
# Epoch 148/150
# 3/3 [==============================] - 7s 2s/step - loss: 1.4088e-05 - accuracy: 1.0000
# Epoch 149/150
# 3/3 [==============================] - 6s 2s/step - loss: 5.1234e-05 - accuracy: 1.0000
# Epoch 150/150
# 3/3 [==============================] - 7s 2s/step - loss: 4.7278e-04 - accuracy: 1.0000
# 1/1 [==============================] - 0s 324ms/step - loss: 30.8266 - accuracy: 0.4118
# Test loss:  30.826642990112305
# Test accuracy:  0.4117647111415863

# %%
accuracy= train.history['accuracy']
loss= train.history['loss']
epochs= range(len(accuracy))

plt.plot(epochs, accuracy, 'bo', label= 'Training accuracy')
plt.plot(epochs, loss, 'r', label= 'Training loss')
plt.show()

# %%
model.save('/content/drive/MyDrive/Colab Notebooks/data/money.h5')

# %%
folder = '/content/drive/MyDrive/ai/testmoney/'
for file in listdir(folder):
  photo = load_img(folder  +  file)
  plt.imshow(photo)
  
  photo = load_img(folder +   file, target_size = (40, 40,3))
  photo=img_to_array(photo)
  photo=photo.astype('float32')
  photo=photo/255
  photo=np.expand_dims(photo,axis=0)
  result=(model.predict(photo).argmax())
  class_name=['5k','10k','50k','20k','500k','200k','100k']
  print(class_name[result])
  plt.show()
# Out:
# 1/1 [==============================] - 0s 57ms/step
# 100k
# 1/1 [==============================] - 0s 58ms/step
# 50k
# 1/1 [==============================] - 0s 49ms/step
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-24-dda95be5855f> in <cell line: 2>()
#      11   result=(model.predict(photo).argmax())
#      12   class_name=['5k','10k','50k','20k','500k','200k','100k']
# ---> 13   print(class_name[result])
#      14   plt.show()
#
# IndexError: list index out of range
