# %% [markdown]
# <a href="https://colab.research.google.com/github/thaohung13/BAO_CAO_GIUA_KY_AI/blob/main/Bai4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#tải tập dữ liệu hình ảnh, chuyển đổi chúng thành mảng NumPy,
#và lưu các mảng này vào đĩa để sử dụng trong quá trình đào tạo hoặc kiểm tra mô hình.
from os import listdir               # lấy danh sách tệp trong thư mục huấn luyện
from numpy import asarray            # chuyển đổi danh sách ảnh và nhãn thành mảng NumPy
from numpy import save               # lưu thành tệp
from keras.utils import load_img     # load_img: để tải ảnh từ tệp
from keras.utils import img_to_array # img_to_array: chuyển đổi thành mảng NumPy
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np
# khai báo các thành phần cần thiết để xây dựng một mô hình mạng neural 
from keras.models import Sequential,Model
from keras.layers import Dense,Flatten,Dropout,Conv2D,MaxPooling2D,Normalization,Input,LeakyReLU
from keras.optimizers import Adam
from keras.losses import categorical_crossentropy
from keras import losses
loss = losses
batch_size = 256
epochs = 135
classes = 6

# %%
# đoạn mã này được sử dụng để tải các tệp ảnh và nhãn tương ứng từ thư mục trên Google Drive
# chuẩn bị chúng cho việc huấn luyện mô hình học máy.
folder = '/content/drive/MyDrive/BAI4/'
photos, labels = list(), list()
for file in listdir(folder):
  output= 0.0
  if file.startswith('Cuc'):
    output= 1.0
  if file.startswith('HoaHong'):
    output= 2.0
  if file.startswith('Mai'):
    output= 3.0
  if file.startswith('Sen'):
    output= 4.0
  if file.startswith('Sung'):
    output= 5.0
  photo = load_img(folder + file, target_size= (40,40))
  photo = img_to_array(photo) # Chuyển đổi ảnh thành một mảng NumPy
  photos.append(photo)  # Thêm mảng ảnh vào danh sách photos
  labels.append(output) # Thêm giá trị output tương ứng vào danh sách labels

# %%
# lưu trữ các mảng numpy photos và labels
photos= asarray(photos) # Chuyển danh sách ảnh thành một mảng NumPy
labels= asarray(labels) # Chuyển danh sách nhãn thành một mảng NumPy
print(photos.shape, labels.shape) # In ra kích thước của mảng ảnh và mảng nhãn
# photos.shape trả về kích thước của mảng photos, được biểu diễn dưới dạng một tuple (số lượng phần tử theo chiều dọc, số lượng phần tử theo chiều ngang, số lượng kênh màu)
# labels.shape: trả về ảnh
save('/content/drive/MyDrive/model/flower/flower_photos', photos)
save('/content/drive/MyDrive/model/flower/flower_labels', labels)
# Out:
# (100, 40, 40, 3) (100,)

# %%
split_index = int(0.2 * len(photos))
test_x, test_y = photos[:split_index], labels[:split_index]
train_x, train_y = photos[split_index:], labels[split_index:]

# %%
print(test_x.shape, train_x.shape)
# Out:
# (20, 40, 40, 3) (80, 40, 40, 3)

# %%
#về khoảng giá trị từ 0 đến 1 bằng cách chia tất cả các giá trị pixel cho 255
train_x = train_x.reshape((80,40, 40, 3))
train_x = train_x.astype('float32')/255

test_x = test_x.reshape((20,40, 40, 3))
test_x = test_x.astype('float32')/255

# %%
from keras.utils import to_categorical
train_y = to_categorical(train_y,6)
test_y = to_categorical(test_y,6)

# %%
# khởi tạo một mô hình mạng neural convolutional (CNN)
model = Sequential()
model.add(Conv2D(32, kernel_size = (3,3), activation = 'linear', input_shape = (40, 40, 3), padding= 'same'))
model.add(LeakyReLU(alpha = 0.1))
model.add(MaxPooling2D((2,2), padding = 'same'))
model.add(Conv2D(64, (3,3), activation = 'linear', padding = 'same'))
model.add(Conv2D(64, (3,3), activation = 'linear', padding = 'same'))
model.add(LeakyReLU(alpha = 0.1))
model.add(MaxPooling2D((2,2), padding = 'same'))
model.add(Conv2D(128, (3,3), activation = 'linear', padding = 'same'))
model.add(LeakyReLU(alpha = 0.1))
model.add(MaxPooling2D((2,2), padding = 'same'))
model.add(Conv2D(256, (3,3), activation = 'linear', padding = 'same'))
model.add(LeakyReLU(alpha = 0.1))
model.add(MaxPooling2D((2,2), padding = 'same'))
model.add(Conv2D(512, (3,3), activation = 'linear', padding = 'same'))
model.add(LeakyReLU(alpha = 0.1))
model.add(MaxPooling2D((2,2), padding = 'same'))
model.add(Conv2D(1024, (3,3), activation = 'linear', padding = 'same'))
model.add(LeakyReLU(alpha = 0.1))

#Đưa vào ANN, bộ ANN để phân loại:
model.add(Flatten())
model.add(Dense(1024, activation = 'linear'))
model.add(Dense(256,activation = 'relu'))
model.add(Dropout(0.25))
model.add(Dense(256,activation = 'relu'))
model.add(Dropout(0.25))
model.add(Dense(256,activation = 'relu'))
model.add(Dropout(0.1))
model.add(Dense(512,activation = 'relu'))
model.add(Dropout(0.25))
model.add(Dense(classes, activation = 'softmax'))
model.summary()
# Out:
# Model: "sequential_43"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_293 (Conv2D)         (None, 40, 40, 32)        896
#
#  leaky_re_lu_238 (LeakyReLU)  (None, 40, 40, 32)       0
#
#  max_pooling2d_207 (MaxPooli  (None, 20, 20, 32)       0
#  ng2D)
#
#  conv2d_294 (Conv2D)         (None, 20, 20, 64)        18496
#
#  conv2d_295 (Conv2D)         (None, 20, 20, 64)        36928
#
#  leaky_re_lu_239 (LeakyReLU)  (None, 20, 20, 64)       0
#
#  max_pooling2d_208 (MaxPooli  (None, 10, 10, 64)       0
#  ng2D)
#
#  conv2d_296 (Conv2D)         (None, 10, 10, 128)       73856
#
#  leaky_re_lu_240 (LeakyReLU)  (None, 10, 10, 128)      0
#
#  max_pooling2d_209 (MaxPooli  (None, 5, 5, 128)        0
#  ng2D)
#
#  conv2d_297 (Conv2D)         (None, 5, 5, 256)         295168
#
#  leaky_re_lu_241 (LeakyReLU)  (None, 5, 5, 256)        0
#
#  max_pooling2d_210 (MaxPooli  (None, 3, 3, 256)        0
#  ng2D)
#
#  conv2d_298 (Conv2D)         (None, 3, 3, 512)         1180160
#
#  leaky_re_lu_242 (LeakyReLU)  (None, 3, 3, 512)        0
#
#  max_pooling2d_211 (MaxPooli  (None, 2, 2, 512)        0
#  ng2D)
#
#  conv2d_299 (Conv2D)         (None, 2, 2, 1024)        4719616
#
#  leaky_re_lu_243 (LeakyReLU)  (None, 2, 2, 1024)       0
#
#  flatten_42 (Flatten)        (None, 4096)              0
#
#  dense_232 (Dense)           (None, 1024)              4195328
#
#  dense_233 (Dense)           (None, 256)               262400
#
#  dropout_164 (Dropout)       (None, 256)               0
#
#  dense_234 (Dense)           (None, 256)               65792
#
#  dropout_165 (Dropout)       (None, 256)               0
#
#  dense_235 (Dense)           (None, 256)               65792
#
#  dropout_166 (Dropout)       (None, 256)               0
#
#  dense_236 (Dense)           (None, 512)               131584
#
#  dropout_167 (Dropout)       (None, 512)               0
#
#  dense_237 (Dense)           (None, 6)                 3078
#
# =================================================================
# Total params: 11,049,094
# Trainable params: 11,049,094
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Compile:
model.compile(optimizer = Adam(), loss = 'categorical_crossentropy', metrics = ['accuracy'])
train = model.fit(train_x, train_y, batch_size= batch_size, epochs= epochs, verbose= 1)
eval = model.evaluate(test_x, test_y)
print('Test loss: ', eval[0])
print('Test accuracy: ', eval[1])
# Out:
# Epoch 1/135
# 1/1 [==============================] - 1s 989ms/step - loss: 1.7874 - accuracy: 0.3250
# Epoch 2/135
# 1/1 [==============================] - 0s 40ms/step - loss: 1.2833 - accuracy: 0.6250
# Epoch 3/135
# 1/1 [==============================] - 0s 40ms/step - loss: 1.4936 - accuracy: 0.6250
# Epoch 4/135
# 1/1 [==============================] - 0s 44ms/step - loss: 1.8624 - accuracy: 0.6250
# Epoch 5/135
# 1/1 [==============================] - 0s 40ms/step - loss: 1.4308 - accuracy: 0.6000
# Epoch 6/135
# 1/1 [==============================] - 0s 37ms/step - loss: 1.6008 - accuracy: 0.5875
# Epoch 7/135
# 1/1 [==============================] - 0s 31ms/step - loss: 1.6118 - accuracy: 0.5875
# Epoch 8/135
# 1/1 [==============================] - 0s 31ms/step - loss: 1.5159 - accuracy: 0.5875
# Epoch 9/135
# 1/1 [==============================] - 0s 31ms/step - loss: 1.2945 - accuracy: 0.5875
# Epoch 10/135
# 1/1 [==============================] - 0s 32ms/step - loss: 1.4219 - accuracy: 0.6125
# Epoch 11/135
# 1/1 [==============================] - 0s 31ms/step - loss: 1.1671 - accuracy: 0.6125
# Epoch 12/135
# 1/1 [==============================] - 0s 30ms/step - loss: 1.1835 - accuracy: 0.6250
# Epoch 13/135
# 1/1 [==============================] - 0s 29ms/step - loss: 1.2178 - accuracy: 0.6250
# Epoch 14/135
# 1/1 [==============================] - 0s 29ms/step - loss: 1.2207 - accuracy: 0.6250
# Epoch 15/135
# 1/1 [==============================] - 0s 31ms/step - loss: 1.1587 - accuracy: 0.6250
# Epoch 16/135
# 1/1 [==============================] - 0s 29ms/step - loss: 1.1327 - accuracy: 0.6250
# Epoch 17/135
# 1/1 [==============================] - 0s 29ms/step - loss: 1.1762 - accuracy: 0.6250
# Epoch 18/135
# 1/1 [==============================] - 0s 30ms/step - loss: 1.1482 - accuracy: 0.6250
# Epoch 19/135
# 1/1 [==============================] - 0s 29ms/step - loss: 1.1406 - accuracy: 0.6250
# Epoch 20/135
# 1/1 [==============================] - 0s 27ms/step - loss: 1.1278 - accuracy: 0.6250
# Epoch 21/135
# 1/1 [==============================] - 0s 26ms/step - loss: 1.0848 - accuracy: 0.6250
# Epoch 22/135
# 1/1 [==============================] - 0s 28ms/step - loss: 1.1378 - accuracy: 0.6250
# Epoch 23/135
# 1/1 [==============================] - 0s 28ms/step - loss: 1.1125 - accuracy: 0.6250
# Epoch 24/135
# 1/1 [==============================] - 0s 29ms/step - loss: 1.0908 - accuracy: 0.6250
# Epoch 25/135
# 1/1 [==============================] - 0s 29ms/step - loss: 1.1141 - accuracy: 0.6250
# Epoch 26/135
# 1/1 [==============================] - 0s 37ms/step - loss: 1.0783 - accuracy: 0.6250
# Epoch 27/135
# 1/1 [==============================] - 0s 28ms/step - loss: 1.1009 - accuracy: 0.6250
# Epoch 28/135
# 1/1 [==============================] - 0s 27ms/step - loss: 1.0745 - accuracy: 0.6250
# Epoch 29/135
# 1/1 [==============================] - 0s 27ms/step - loss: 1.0447 - accuracy: 0.6250
# Epoch 30/135
# 1/1 [==============================] - 0s 27ms/step - loss: 1.0333 - accuracy: 0.6250
# Epoch 31/135
# 1/1 [==============================] - 0s 27ms/step - loss: 1.0553 - accuracy: 0.6250
# Epoch 32/135
# 1/1 [==============================] - 0s 29ms/step - loss: 1.0308 - accuracy: 0.6250
# Epoch 33/135
# 1/1 [==============================] - 0s 29ms/step - loss: 0.9527 - accuracy: 0.6250
# Epoch 34/135
# 1/1 [==============================] - 0s 29ms/step - loss: 0.9466 - accuracy: 0.6250
# Epoch 35/135
# 1/1 [==============================] - 0s 28ms/step - loss: 1.0451 - accuracy: 0.6250
# Epoch 36/135
# 1/1 [==============================] - 0s 27ms/step - loss: 0.9629 - accuracy: 0.6250
# Epoch 37/135
# 1/1 [==============================] - 0s 28ms/step - loss: 0.9261 - accuracy: 0.6250
# Epoch 38/135
# 1/1 [==============================] - 0s 28ms/step - loss: 0.8739 - accuracy: 0.6250
# Epoch 39/135
# 1/1 [==============================] - 0s 27ms/step - loss: 0.8570 - accuracy: 0.6250
# Epoch 40/135
# 1/1 [==============================] - 0s 27ms/step - loss: 0.8382 - accuracy: 0.6250
# Epoch 41/135
# 1/1 [==============================] - 0s 28ms/step - loss: 0.8430 - accuracy: 0.6250
# Epoch 42/135
# 1/1 [==============================] - 0s 27ms/step - loss: 0.8928 - accuracy: 0.6250
# Epoch 43/135
# 1/1 [==============================] - 0s 26ms/step - loss: 0.8326 - accuracy: 0.6375
# Epoch 44/135
# 1/1 [==============================] - 0s 28ms/step - loss: 0.8411 - accuracy: 0.6250
# Epoch 45/135
# 1/1 [==============================] - 0s 29ms/step - loss: 0.7813 - accuracy: 0.6500
# Epoch 46/135
# 1/1 [==============================] - 0s 27ms/step - loss: 0.7594 - accuracy: 0.6875
# Epoch 47/135
# 1/1 [==============================] - 0s 27ms/step - loss: 0.7630 - accuracy: 0.6750
# Epoch 48/135
# 1/1 [==============================] - 0s 27ms/step - loss: 0.7209 - accuracy: 0.7250
# Epoch 49/135
# 1/1 [==============================] - 0s 32ms/step - loss: 0.6976 - accuracy: 0.6875
# Epoch 50/135
# 1/1 [==============================] - 0s 27ms/step - loss: 0.6697 - accuracy: 0.7625
# Epoch 51/135
# 1/1 [==============================] - 0s 27ms/step - loss: 0.6237 - accuracy: 0.8125
# Epoch 52/135
# 1/1 [==============================] - 0s 27ms/step - loss: 0.9857 - accuracy: 0.7000
# Epoch 53/135
# 1/1 [==============================] - 0s 26ms/step - loss: 0.9732 - accuracy: 0.6250
# Epoch 54/135
# 1/1 [==============================] - 0s 27ms/step - loss: 0.7670 - accuracy: 0.7000
# Epoch 55/135
# 1/1 [==============================] - 0s 28ms/step - loss: 0.7942 - accuracy: 0.6500
# Epoch 56/135
# 1/1 [==============================] - 0s 27ms/step - loss: 0.7574 - accuracy: 0.6500
# Epoch 57/135
# 1/1 [==============================] - 0s 34ms/step - loss: 0.7607 - accuracy: 0.6750
# Epoch 58/135
# 1/1 [==============================] - 0s 26ms/step - loss: 0.6436 - accuracy: 0.7250
# Epoch 59/135
# 1/1 [==============================] - 0s 27ms/step - loss: 0.6931 - accuracy: 0.7375
# Epoch 60/135
# 1/1 [==============================] - 0s 27ms/step - loss: 0.8508 - accuracy: 0.6375
# Epoch 61/135
# 1/1 [==============================] - 0s 27ms/step - loss: 0.7247 - accuracy: 0.6750
# Epoch 62/135
# 1/1 [==============================] - 0s 27ms/step - loss: 0.7874 - accuracy: 0.6500
# Epoch 63/135
# 1/1 [==============================] - 0s 27ms/step - loss: 0.6430 - accuracy: 0.7000
# Epoch 64/135
# 1/1 [==============================] - 0s 28ms/step - loss: 0.6412 - accuracy: 0.6625
# Epoch 65/135
# 1/1 [==============================] - 0s 27ms/step - loss: 0.6390 - accuracy: 0.7000
# Epoch 66/135
# 1/1 [==============================] - 0s 28ms/step - loss: 0.6127 - accuracy: 0.7125
# Epoch 67/135
# 1/1 [==============================] - 0s 26ms/step - loss: 0.5778 - accuracy: 0.7375
# Epoch 68/135
# 1/1 [==============================] - 0s 27ms/step - loss: 0.5587 - accuracy: 0.7250
# Epoch 69/135
# 1/1 [==============================] - 0s 28ms/step - loss: 0.5455 - accuracy: 0.7625
# Epoch 70/135
# 1/1 [==============================] - 0s 27ms/step - loss: 0.5467 - accuracy: 0.7125
# Epoch 71/135
# 1/1 [==============================] - 0s 27ms/step - loss: 0.5106 - accuracy: 0.7000
# Epoch 72/135
# 1/1 [==============================] - 0s 28ms/step - loss: 0.5761 - accuracy: 0.8000
# Epoch 73/135
# 1/1 [==============================] - 0s 28ms/step - loss: 0.5071 - accuracy: 0.8000
# Epoch 74/135
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4351 - accuracy: 0.8000
# Epoch 75/135
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4457 - accuracy: 0.8250
# Epoch 76/135
# 1/1 [==============================] - 0s 30ms/step - loss: 0.4240 - accuracy: 0.8375
# Epoch 77/135
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3888 - accuracy: 0.8625
# Epoch 78/135
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4068 - accuracy: 0.7750
# Epoch 79/135
# 1/1 [==============================] - 0s 33ms/step - loss: 0.3479 - accuracy: 0.8250
# Epoch 80/135
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3823 - accuracy: 0.8250
# Epoch 81/135
# 1/1 [==============================] - 0s 31ms/step - loss: 0.3081 - accuracy: 0.8250
# Epoch 82/135
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3549 - accuracy: 0.8250
# Epoch 83/135
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3010 - accuracy: 0.8625
# Epoch 84/135
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3222 - accuracy: 0.8375
# Epoch 85/135
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3347 - accuracy: 0.8125
# Epoch 86/135
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3061 - accuracy: 0.8250
# Epoch 87/135
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3234 - accuracy: 0.8250
# Epoch 88/135
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2867 - accuracy: 0.8500
# Epoch 89/135
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3332 - accuracy: 0.8500
# Epoch 90/135
# 1/1 [==============================] - 0s 26ms/step - loss: 0.2867 - accuracy: 0.8625
# Epoch 91/135
# 1/1 [==============================] - 0s 31ms/step - loss: 0.5727 - accuracy: 0.8250
# Epoch 92/135
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4039 - accuracy: 0.8125
# Epoch 93/135
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4909 - accuracy: 0.7750
# Epoch 94/135
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3899 - accuracy: 0.8000
# Epoch 95/135
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3384 - accuracy: 0.8500
# Epoch 96/135
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3675 - accuracy: 0.8250
# Epoch 97/135
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3574 - accuracy: 0.8000
# Epoch 98/135
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3462 - accuracy: 0.8375
# Epoch 99/135
# 1/1 [==============================] - 0s 34ms/step - loss: 0.3085 - accuracy: 0.8750
# Epoch 100/135
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3212 - accuracy: 0.8250
# Epoch 101/135
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3028 - accuracy: 0.8375
# Epoch 102/135
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3139 - accuracy: 0.8250
# Epoch 103/135
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3004 - accuracy: 0.8500
# Epoch 104/135
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3003 - accuracy: 0.8250
# Epoch 105/135
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2993 - accuracy: 0.8375
# Epoch 106/135
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2922 - accuracy: 0.8250
# Epoch 107/135
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2908 - accuracy: 0.8000
# Epoch 108/135
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3108 - accuracy: 0.8125
# Epoch 109/135
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2575 - accuracy: 0.8750
# Epoch 110/135
# 1/1 [==============================] - 0s 26ms/step - loss: 0.2832 - accuracy: 0.8250
# Epoch 111/135
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2995 - accuracy: 0.8125
# Epoch 112/135
# 1/1 [==============================] - 0s 25ms/step - loss: 0.2790 - accuracy: 0.8125
# Epoch 113/135
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2683 - accuracy: 0.8125
# Epoch 114/135
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2767 - accuracy: 0.8000
# Epoch 115/135
# 1/1 [==============================] - 0s 27ms/step - loss: 0.2534 - accuracy: 0.8500
# Epoch 116/135
# 1/1 [==============================] - 0s 27ms/step - loss: 0.2906 - accuracy: 0.8000
# Epoch 117/135
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2769 - accuracy: 0.8500
# Epoch 118/135
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2486 - accuracy: 0.8625
# Epoch 119/135
# 1/1 [==============================] - 0s 27ms/step - loss: 0.2864 - accuracy: 0.8500
# Epoch 120/135
# 1/1 [==============================] - 0s 27ms/step - loss: 0.2579 - accuracy: 0.8750
# Epoch 121/135
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2865 - accuracy: 0.8250
# Epoch 122/135
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2892 - accuracy: 0.8125
# Epoch 123/135
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2544 - accuracy: 0.8625
# Epoch 124/135
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2702 - accuracy: 0.8500
# Epoch 125/135
# 1/1 [==============================] - 0s 26ms/step - loss: 0.2780 - accuracy: 0.8250
# Epoch 126/135
# 1/1 [==============================] - 0s 26ms/step - loss: 0.2646 - accuracy: 0.8125
# Epoch 127/135
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2950 - accuracy: 0.8125
# Epoch 128/135
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2579 - accuracy: 0.8375
# Epoch 129/135
# 1/1 [==============================] - 0s 27ms/step - loss: 0.2659 - accuracy: 0.8625
# Epoch 130/135
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2446 - accuracy: 0.8375
# Epoch 131/135
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2414 - accuracy: 0.8375
# Epoch 132/135
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2806 - accuracy: 0.8375
# Epoch 133/135
# 1/1 [==============================] - 0s 29ms/step - loss: 0.2433 - accuracy: 0.8500
# Epoch 134/135
# 1/1 [==============================] - 0s 26ms/step - loss: 0.2604 - accuracy: 0.8125
# Epoch 135/135
# 1/1 [==============================] - 0s 27ms/step - loss: 0.2458 - accuracy: 0.8500
# 1/1 [==============================] - 0s 237ms/step - loss: 5.7016 - accuracy: 0.5000
# Test loss:  5.701565742492676
# Test accuracy:  0.5

# %%
accuracy= train.history['accuracy']
loss= train.history['loss']
epochs= range(len(accuracy))

plt.plot(epochs, accuracy, 'bo', label= 'Training accuracy')
plt.plot(epochs, loss, 'r', label= 'Training loss')
plt.show()

# %%
#model.save('/content/drive/MyDrive/Colab Notebooks/data/flower.h5')

# %%
folder = '/content/drive/MyDrive/ai/testflower/'
for file in listdir(folder):
  photo = load_img(folder  +  file)
  plt.imshow(photo)
  
  photo = load_img(folder +   file, target_size = (40, 40))
  photo=img_to_array(photo)
  photo=photo.astype('float32')
  photo=photo/255
  photo=np.expand_dims(photo,axis=0)
  result=(model.predict(photo).argmax())
  class_name=['','Cuc','HoaHong','Mai','Sen','Sung']
  print(class_name[result])
  plt.show()
# Out:
# 1/1 [==============================] - 0s 142ms/step
# Mai
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
